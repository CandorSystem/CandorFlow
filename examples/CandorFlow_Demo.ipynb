# %% [markdown]
# #  CandorFlow — Training Stability Demo (Public Edition)
#
# This notebook demonstrates the minimal, safe public edition of CandorFlow:
# - TinyModel training demo
# - Simplified λ(t) stability metric
# - StabilityController (rollback + LR decay)
# - Synthetic instability spike
# - Two plots: lambda_curve and stability_phases
#
# This is NOT the full CandorFlow engine. All proprietary physics and
# cross-domain algorithms are intentionally excluded.

# %%
# !pip install -q candorflow

# %%
from candorflow.demo import run_demo, plot_results

results = run_demo()
plot_results(results)

print("Demo complete.")

# %% [markdown]
# ##  Outputs
# The demo will generate and display:
# - `lambda_curve.png`
# - `stability_phases.png`
#
# Both plots reflect the simplified CandorFlow stability metric,
# synthetic spike, rollback, and adaptive learning-rate correction.

# %% [markdown]
# ##  Note
# This public edition excludes:
# - universal scaling laws
# - reflexive ridge equations
# - cross-domain invariants
# - catastrophe foresight horizon
# - RL, 8B, and multi-signal fusion logic
#
# The full CandorFlow engine is available only under private review.
